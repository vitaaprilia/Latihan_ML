# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/adm_data.csv')
df
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# ..          ...        ...          ...                ...  ...   ...   ...
# 395         396        324          110                  3  3.5   3.5  9.04
# 396         397        325          107                  3  3.0   3.5  9.11
# 397         398        330          116                  4  5.0   4.5  9.45
# 398         399        312          103                  3  3.5   4.0  8.78
# 399         400        333          117                  4  5.0   4.0  9.66
#
#      Research  Chance of Admit
# 0           1              0.92
# 1           1              0.76
# 2           1              0.72
# 3           1              0.80
# 4           0              0.65
# ..        ...               ...
# 395         1              0.82
# 396         1              0.84
# 397         1              0.91
# 398         0              0.67
# 399         1              0.95
#
# [400 rows x 9 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Serial No.         400 non-null    int64
#  1   GRE Score          400 non-null    int64
#  2   TOEFL Score        400 non-null    int64
#  3   University Rating  400 non-null    int64
#  4   SOP                400 non-null    float64
#  5   LOR                400 non-null    float64
#  6   CGPA               400 non-null    float64
#  7   Research           400 non-null    int64
#  8   Chance of Admit    400 non-null    float64
# dtypes: float64(4), int64(5)
# memory usage: 28.2 KB

# %%
df.isnull().sum()
# Out:
# Serial No.           0
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(), annot=True)

# %%
x = df.drop(['Chance of Admit '], axis=1)
y = df['Chance of Admit ']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,
                                                    y,
                                                    test_size=0.2,
                                                   )

# %%
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
mse = []
mae = []
r2 = []

# Import model machine learning
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.neighbors import KNeighborsRegressor
from xgboost import XGBRegressor

lr = LinearRegression()
rf = RandomForestRegressor()
gbr = GradientBoostingRegressor()
knn = KNeighborsRegressor()
xgb = XGBRegressor()

models = [lr,rf,gbr,knn,xgb]

for i in models:
  i.fit(x_train,y_train)
  y_pred = i.predict(x_test)
  mse.append(round(np.sqrt(mean_squared_error(y_test,y_pred)),2))
  mae.append(round(np.sqrt(mean_absolute_error(y_test,y_pred)),2))
  r2.append(round(r2_score(y_test,y_pred),2))

  print(f'model: {i} and rmse score is: {round(np.sqrt(mean_squared_error(y_test, y_pred)), 2)}, mae score is: {round(np.sqrt(mean_absolute_error(y_test, y_pred)), 2)} r2_score is: {round(r2_score(y_test, y_pred), 2)}')

model_names = ['LinearRegression','RandomForestRegressor', 'GradientBoostRegressor', 'KNeighborsRegressor','XGBRegressor']

result_df = pd.DataFrame({'RMSE': mse, 'MAE': mae, 'R2_SCORE': r2}, index = model_names)
result_df
# Out:
# model: LinearRegression() and rmse score is: 0.06, mae score is: 0.21 r2_score is: 0.83
# model: RandomForestRegressor() and rmse score is: 0.06, mae score is: 0.21 r2_score is: 0.81
# model: GradientBoostingRegressor() and rmse score is: 0.05, mae score is: 0.19 r2_score is: 0.85
# model: KNeighborsRegressor() and rmse score is: 0.08, mae score is: 0.23 r2_score is: 0.68
# [04:00:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# model: XGBRegressor() and rmse score is: 0.05, mae score is: 0.19 r2_score is: 0.86
#                         RMSE   MAE  R2_SCORE
# LinearRegression        0.06  0.21      0.83
# RandomForestRegressor   0.06  0.21      0.81
# GradientBoostRegressor  0.05  0.19      0.85
# KNeighborsRegressor     0.08  0.23      0.68
# XGBRegressor            0.05  0.19      0.86

# %%
#  Regression Score of the model
print('Score For Train Data : {}'.format(lr.score(x_train,y_train)))
print('Score For Test Data : {}'.format(lr.score(x_test,y_test)))
# Out:
# Score For Train Data : 0.8144484915993402
# Score For Test Data : 0.8304323761852452

# %%
sns.scatterplot(x=y_test, y=y_pred);
plt.xlabel('y_test')
plt.ylabel('predictions')
# Out:
# Text(0, 0.5, 'predictions')
