# %% [markdown]
# https://www.kaggle.com/datasets/fedesoriano/stroke-prediction-dataset
#
# **Stroke Prediction Classification**  ***oke***

# %% [markdown]
#  **Heart Attack Prediction**  ***oke***
#
# https://www.kaggle.com/datasets/andrewmvd/heart-failure-clinical-data
#
# https://www.kaggle.com/code/rachelz0/heart-failure-prediction

# %% [markdown]
# **HEALTH INSURANCE CROSS SELL**
#
# https://www.kaggle.com/datasets/anmolkumar/health-insurance-cross-sell-prediction/code
#
# https://www.kaggle.com/code/sudhanshu2198/health-insurance-cross-sell-prediction
#
# https://www.kaggle.com/code/nguyenthicamlai/logisticregression-randomforest-decisiontree

# %% [markdown]
#  **Harry Potter Cluestering**
#
# https://www.kaggle.com/datasets/adnananam/harry-potter-dataset

# %% [markdown]
# **Unsupervised Learning on Country Data**
#
# https://www.kaggle.com/datasets/rohan0301/unsupervised-learning-on-country-data
#
# https://www.kaggle.com/code/tanmay111999/clustering-pca-k-means-dbscan-hierarchical

# %% [markdown]
# **Iron Deficiency Prediction Classification**
#
# https://www.kaggle.com/datasets/ahmadjalalmasood123/deaths-by-risk-factor-dataset/code
#
# https://www.kaggle.com/code/gautamchettiar/analysis-iron-deficiency-prediction-xgb-99-78

# %% [markdown]
# **Online Retail K-means & Hierarchical Clustering K-means and Hierarchical Clustering**
#
# https://www.kaggle.com/datasets/hellbuoy/online-retail-customer-clustering/code
#
# https://www.kaggle.com/code/xiangzxzx/rfm-cluster-analysis-for-online-retail

# %% [markdown]
# **Income Dataset Perform Binary Classification to predict if Salary is greater than $50K => 195 Materi Machine Learning**
#
# https://www.kaggle.com/datasets/mastmustu/income
#
# https://www.kaggle.com/code/mastmustu/income-data-dt-segmentation

# %% [markdown]
# **Linear Regression**
#
#
# Cara Menggunakan model machine learning dari training data untuk melakukan prediksi dengan file berbeda
# https://www.kaggle.com/code/anhvutruong/linear-regression
